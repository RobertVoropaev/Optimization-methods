# %% [markdown]
# # Оптимальные методы первого порядка

# %% [markdown]
# ## Исследуемая функция

# %%
import numpy as np
import scipy.linalg as la

def f(x):
    return (x[0] - 1)**2 / 8 + (x[1] - 2)**2 / 3
    
def df_1(x):
    return (x[0] - 1) / 4

def df_2(x):
    return 2  / 3  * (x[1] - 2)
 
def grad(x):
    return np.array([df_1(x) , df_2(x)])

# %% [markdown]
# ## Метод наискорейшего спуска

# %% [markdown]
# ### При постоянном $\lambda$

# %%
n = 1000
eps = 1e-10
x = np.zeros((n, 2))

lamb_const = 1/2
x[0] = 10., 10.
i = 0
print(i, x[i])

x[i + 1] = x[i] - lamb_const * grad(x[i])
print(i + 1, x[i + 1])

while la.norm(x[i + 1] - x[i]) > eps:
    i += 1
    x[i + 1] = x[i] - lamb_const * grad(x[i])
    print(i + 1, x[i + 1])

i += 1
print("Result:", x[i], "on step:", i)
# Out:
# 0 [10. 10.]
# 1 [8.875      7.33333333]
# 2 [7.890625   5.55555556]
# 3 [7.02929688 4.37037037]
# 4 [6.27563477 3.58024691]
# 5 [5.61618042 3.05349794]
# 6 [5.03915787 2.70233196]
# 7 [4.53426313 2.46822131]
# 8 [4.09248024 2.31214754]
# 9 [3.70592021 2.20809836]
# 10 [3.36768019 2.13873224]
# 11 [3.07172016 2.09248816]
# 12 [2.81275514 2.06165877]
# 13 [2.58616075 2.04110585]
# 14 [2.38789066 2.0274039 ]
# 15 [2.21440432 2.01826927]
# 16 [2.06260378 2.01217951]
# 17 [1.92977831 2.00811967]
# 18 [1.81355602 2.00541312]
# 19 [1.71186152 2.00360874]
# 20 [1.62287883 2.00240583]
# 21 [1.54501898 2.00160389]
# 22 [1.4768916  2.00106926]
# 23 [1.41728015 2.00071284]
# 24 [1.36512013 2.00047523]
# 25 [1.31948012 2.00031682]
# 26 [1.2795451  2.00021121]
# 27 [1.24460196 2.00014081]
# 28 [1.21402672 2.00009387]
# 29 [1.18727338 2.00006258]
# 30 [1.16386421 2.00004172]
# 31 [1.14338118 2.00002781]
# 32 [1.12545853 2.00001854]
# 33 [1.10977622 2.00001236]
# 34 [1.09605419 2.00000824]
# 35 [1.08404742 2.00000549]
# 36 [1.07354149 2.00000366]
# 37 [1.0643488  2.00000244]
# 38 [1.0563052  2.00000163]
# 39 [1.04926705 2.00000109]
# 40 [1.04310867 2.00000072]
# 41 [1.03772009 2.00000048]
# 42 [1.03300508 2.00000032]
# 43 [1.02887944 2.00000021]
# 44 [1.02526951 2.00000014]
# 45 [1.02211082 2.0000001 ]
# 46 [1.01934697 2.00000006]
# 47 [1.0169286  2.00000004]
# 48 [1.01481252 2.00000003]
# 49 [1.01296096 2.00000002]
# 50 [1.01134084 2.00000001]
# 51 [1.00992323 2.00000001]
# 52 [1.00868283 2.00000001]
# 53 [1.00759748 2.        ]
# 54 [1.00664779 2.        ]
# 55 [1.00581682 2.        ]
# 56 [1.00508972 2.        ]
# 57 [1.0044535 2.       ]
# 58 [1.00389681 2.        ]
# 59 [1.00340971 2.        ]
# 60 [1.0029835 2.       ]
# 61 [1.00261056 2.        ]
# 62 [1.00228424 2.        ]
# 63 [1.00199871 2.        ]
# 64 [1.00174887 2.        ]
# 65 [1.00153026 2.        ]
# 66 [1.00133898 2.        ]
# 67 [1.00117161 2.        ]
# 68 [1.00102516 2.        ]
# 69 [1.00089701 2.        ]
# 70 [1.00078489 2.        ]
# 71 [1.00068677 2.        ]
# 72 [1.00060093 2.        ]
# 73 [1.00052581 2.        ]
# 74 [1.00046009 2.        ]
# 75 [1.00040257 2.        ]
# 76 [1.00035225 2.        ]
# 77 [1.00030822 2.        ]
# 78 [1.00026969 2.        ]
# 79 [1.00023598 2.        ]
# 80 [1.00020648 2.        ]
# 81 [1.00018067 2.        ]
# 82 [1.00015809 2.        ]
# 83 [1.00013833 2.        ]
# 84 [1.00012104 2.        ]
# 85 [1.00010591 2.        ]
# 86 [1.00009267 2.        ]
# 87 [1.00008109 2.        ]
# 88 [1.00007095 2.        ]
# 89 [1.00006208 2.        ]
# 90 [1.00005432 2.        ]
# 91 [1.00004753 2.        ]
# 92 [1.00004159 2.        ]
# 93 [1.00003639 2.        ]
# 94 [1.00003184 2.        ]
# 95 [1.00002786 2.        ]
# 96 [1.00002438 2.        ]
# 97 [1.00002133 2.        ]
# 98 [1.00001867 2.        ]
# 99 [1.00001633 2.        ]
# 100 [1.00001429 2.        ]
# 101 [1.0000125 2.       ]
# 102 [1.00001094 2.        ]
# 103 [1.00000957 2.        ]
# 104 [1.00000838 2.        ]
# 105 [1.00000733 2.        ]
# 106 [1.00000641 2.        ]
# 107 [1.00000561 2.        ]
# 108 [1.00000491 2.        ]
# 109 [1.0000043 2.       ]
# 110 [1.00000376 2.        ]
# 111 [1.00000329 2.        ]
# 112 [1.00000288 2.        ]
# 113 [1.00000252 2.        ]
# 114 [1.0000022 2.       ]
# 115 [1.00000193 2.        ]
# 116 [1.00000169 2.        ]
# 117 [1.00000148 2.        ]
# 118 [1.00000129 2.        ]
# 119 [1.00000113 2.        ]
# 120 [1.00000099 2.        ]
# 121 [1.00000087 2.        ]
# 122 [1.00000076 2.        ]
# 123 [1.00000066 2.        ]
# 124 [1.00000058 2.        ]
# 125 [1.00000051 2.        ]
# 126 [1.00000044 2.        ]
# 127 [1.00000039 2.        ]
# 128 [1.00000034 2.        ]
# 129 [1.0000003 2.       ]
# 130 [1.00000026 2.        ]
# 131 [1.00000023 2.        ]
# 132 [1.0000002 2.       ]
# 133 [1.00000017 2.        ]
# 134 [1.00000015 2.        ]
# 135 [1.00000013 2.        ]
# 136 [1.00000012 2.        ]
# 137 [1.0000001 2.       ]
# 138 [1.00000009 2.        ]
# 139 [1.00000008 2.        ]
# 140 [1.00000007 2.        ]
# 141 [1.00000006 2.        ]
# 142 [1.00000005 2.        ]
# 143 [1.00000005 2.        ]
# 144 [1.00000004 2.        ]
# 145 [1.00000004 2.        ]
# 146 [1.00000003 2.        ]
# 147 [1.00000003 2.        ]
# 148 [1.00000002 2.        ]
# 149 [1.00000002 2.        ]
# 150 [1.00000002 2.        ]
# 151 [1.00000002 2.        ]
# 152 [1.00000001 2.        ]
# 153 [1.00000001 2.        ]
# 154 [1.00000001 2.        ]
# 155 [1.00000001 2.        ]
# 156 [1.00000001 2.        ]
# 157 [1.00000001 2.        ]
# 158 [1.00000001 2.        ]
# 159 [1.00000001 2.        ]
# 160 [1. 2.]
# 161 [1. 2.]
# 162 [1. 2.]
# 163 [1. 2.]
# 164 [1. 2.]
# 165 [1. 2.]
# 166 [1. 2.]
# 167 [1. 2.]
# 168 [1. 2.]
# 169 [1. 2.]
# 170 [1. 2.]
# 171 [1. 2.]
# 172 [1. 2.]
# 173 [1. 2.]
# 174 [1. 2.]
# 175 [1. 2.]
# Result: [1. 2.] on step: 175

# %% [markdown]
# ### При переменном $\lambda$

# %%
n = 1000
eps = 1e-10
x = np.zeros((n, 2))

lamb = np.zeros(n)
def cal_lamb(x, i):
    a = grad(x[i])[0]
    b = grad(x[i])[1]
    xx = x[i][0]
    yy = x[i][1]
    return (a**2 + b**2) / (0.25 * a**2 + b**2 *2 / 3)
    
x[0] = 10., 10.
i = 0
print(i, x[i])

lamb[i] = cal_lamb(x, i)
x[i + 1] = x[i] - lamb[i] * grad(x[i])
print(i + 1, x[i + 1])

while la.norm(x[i + 1] - x[i]) > eps:
    i += 1
    lamb[i] = cal_lamb(x, i)
    x[i + 1] = x[i] - lamb[i] * grad(x[i])
    print(i + 1, x[i + 1])

i += 1
print("Result:", x[i], "on step:", i)
# Out:
# 0 [10. 10.]
# 1 [6.27306537 1.16578458]
# 2 [2.06072424 2.94286599]
# 3 [1.62147425 1.90168083]
# 4 [1.1250151  2.11112454]
# 5 [1.07324587 1.98841227]
# 6 [1.01473406 2.01309694]
# 7 [1.00863263 1.99863429]
# 8 [1.00173653 2.00154358]
# 9 [1.00101743 1.99983904]
# 10 [1.00020466 2.00018192]
# 11 [1.00011991 1.99998103]
# 12 [1.00002412 2.00002144]
# 13 [1.00001413 1.99999776]
# 14 [1.00000284 2.00000253]
# 15 [1.00000167 1.99999974]
# 16 [1.00000034 2.0000003 ]
# 17 [1.0000002  1.99999997]
# 18 [1.00000004 2.00000004]
# 19 [1.00000002 2.        ]
# 20 [1. 2.]
# 21 [1. 2.]
# 22 [1. 2.]
# 23 [1. 2.]
# 24 [1. 2.]
# 25 [1. 2.]
# Result: [1. 2.] on step: 25

# %% [markdown]
# ## Метод покоординатного спука Гаусса — Зейделя

# %% [markdown]
# ## Метод сопряженных градиентов
